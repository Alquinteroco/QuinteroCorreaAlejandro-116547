# %%
#%%EJERCICIO 1

while True:
    try:
        n = float(input('Digite un número: ')) #INGRESAMOS UN NUMERO
        if n>0 or n<=0:                        #PUEDE SER DECIMAL
            break
        else:
            print('El caracter ingresado no es una cantidad numérica ')
    except:
        print('El caracter ingresado no es una cantidad numérica ')

if n<0:
    print("El valor absoluto es:")
    print(n*-1) #SI ES NEGATIVO EL NUMERO, LO MULTIPLICAMOS POR -1
if n>=0:
    print('El valor absoluto es:')
    print(n) #SI ES POSITIVO, IMPRIMIRLO IGUAL
# Out:
# Digite un número: 85
# El valor absoluto es:
# 85.0

# %%
#%% EJERCICIO 2

num1 = int(input("Ingrese el primer número: "))
num2 = int(input("Ingrese el segundo número: "))
numero= num1-num2
print(numero)
valor= range(2,numero)
contador = 0
for n in valor:
  if numero % n == 0:
    contador +=1
    print("divisor:", n)
if contador > 0 :
  print("El número no es primo" )
else:
  print("El número es primo")
# Out:
# Ingrese el primer número: 1
# Ingrese el segundo número: 3
# -2
# El número es primo

# %%
#%% EJERCICIO 3

def multiple(valor, multiple):
    resto = valor % multiple
    if resto == 0:
        return True
    else:
        return False
 
multiples_3 = []
multiples_4 = []

 
# bucle del 1 al 100
for i in range(1,101):
 
    if multiple(i,3):
        multiples_3.append(i)
 
    if multiple(i,4):
        multiples_4.append(i)
 
print ("Los multiples de 3 son:", multiples_3[1:16])
print ("Los multiples de 4 son:", multiples_4)
# Out:
# Los multiples de 3 son: [6, 9, 12, 15, 18, 21, 24, 27, 30, 33, 36, 39, 42, 45, 48]
# Los multiples de 4 son: [4, 8, 12, 16, 20, 24, 28, 32, 36, 40, 44, 48, 52, 56, 60, 64, 68, 72, 76, 80, 84, 88, 92, 96, 100]

# %%
#%% EJERCICIO 5

def leer_frase():
    global txt
    txt = (input("Ingrese una frase: "))
def contar_vocales():
    vocal_Mayus = ["A","E","I","O","U","Á","É","Í","Ó","Ú"]
    cont_vocM=0
    for i in vocal_Mayus:
        for j in txt:
            if(i==j):
                cont_vocM += 1
    print("El número de vocales MAYÚSCULAS es: ",cont_vocM)
    
def contar_tildes():
    vocal_tildes = ["Á","á","É","é","Í","í","Ó","ó","Ú","ú"]
    cont_vocT=0
    for i in vocal_tildes:
        for j in txt:
            if(i==j):
                cont_vocT += 1
    print("El número de vocales con tilde es: ",cont_vocT)

def contar_digitos():
    digitos = ["1","2","3","4","5","6","7","8","9","0"]
    cont_dig=0
    for i in digitos:
        for j in txt:
            if(i==j):
                cont_dig += 1
    print("El número de digitos es: ",cont_dig)
    
def contar_espacios():
    espacios = [" "]
    cont_esp=0
    for i in espacios:
        for j in txt:
            if(i==j):
                cont_esp += 1
    print("El número de espacios es: ",cont_esp)

leer_frase()
contar_vocales()
contar_tildes()
contar_digitos()
contar_espacios()

# %%
##% EJERCICIO 4

import math as mt

input('Por favor ingrese coordenadas centro y radio del circulo 1') 

x1 = float(input('Coordenada en x:'))
y1 = float(input('Coordenada en y: '))
r1 = float(input(' Radio:  '))

input('Por favor ingrese coordenadas centro y radio del circulo 2')

x2 = float(input('Coordenada en x:')) #
y2 = float(input('Coordenada en y: '))
r2 = float(input(' Radio:  '))

input(' Ingrese coordenadas de un punto') 

a = float(input('Coordenada en x del punto:'))
b = float(input('Coordenada en y del punto: '))
k1 = mt.sqrt(((a-x1)**2 + (b-y1)**2)) 
k2 = mt.sqrt(((a-x2)**2 + (b-y2)**2)) 

if k1 <= r1 and k2>r2:
    print(' Está dentro del circulo 1')
    
if k2 <=r2 and k1 >= r1:
    print('Está dentro del circulo 2')
    
if k1 >r1 and k2>r2:
    print('Está fuera de ambos circulos')
    
if k1 <=r1 and k2 <= r2:
    print(' Está dentro de ambos circulos')
# Out:
# Por favor ingrese coordenadas centro y radio del circulo 1[2,1,5]
# Coordenada en x:6
# Coordenada en y: 5
#  Radio:  3
# Por favor ingrese coordenadas centro y radio del circulo 2[1,7,6]
# Coordenada en x:8
# Coordenada en y: 6
#  Radio:  1
#  Ingrese coordenadas de un punto[1,3]
# Coordenada en x del punto:6
# Coordenada en y del punto: 2
#  Está dentro del circulo 1

# %%
#%%EJERCICIO 6

def leer_frase():
    global x
    x = (input("Ingrese una frase: "))
 
    x = x.replace(" ", "")
 
    x = sorted(x)
  
    x = "".join(x)
 
leer_frase()
print(x)

# %%
#%% EJERCICIO 7

x = eval(input('Esccriba una lista ordenada de manera ascendente: '))
y = 0
z = 0
w = x[0] 

for i in x[1:len(x)+1]:
    if w > i:
        c = z
        print('A organizar lista!')
        break
    w = x[y+1]  
    y = y+1
    
if z == 0:
    h=-1
    x1 = float(input('ingresar numero: '))
    for i in x:  
        h=h+1
        if x1<=i: 
            x1.insert(h,x1)
            break
        if h==(len(x)-1):
            x.append(x1)
            break
            
print(x)

# %%
#%% EJERCICIO 8

x = eval(input('ingrese una lista: ')) #[-n,...,n]
t = x[0]
g = 0

for i in x[1:len(x)+1]:
    g = g+1
    if t<i:
        t==i
        
x.remove(t)
t = x[0]
for i in x[1:len(x)+1]:
    g = g+1
    if t<i:
        t = i
        
print('el segundo numero mas grande es: ') 
print(t)

# %%
#%% EJERCICIO 9

numero = int(input("Ingresar el número: "))
valor = numero

while(valor > 1):
    if(valor % 2 == 0):
        valor = (valor / 2)
        print(str(valor)+ " ")
        
    else:
        valor = (valor * 3) + 1
        print( str(valor)+" ")

# %%
#%% EJERCICIO 10

import random

def main():
    print("OPERACIONES (1)")
    print("Escriba el resultado de las siguientes operaciones:")

    correctas = 0

    while correctas < 5:
        a = random.randrange(1, 101)
        b = random.randrange(1, 101)
        respuesta = int(input(f"{a} + {b} = "))
        if respuesta == a + b:
            correctas += 1
            print("Respuesta correcta")
        else:
            print("Respuesta incorrecta")
        print()

    print("Programa terminado.")


if __name__ == "__main__":
    main()

# %%
#%% EJERCICIO 11

def rectangulo(ancho, alto, letra):
    for i in range(alto):
        for j in range(ancho):
            print(letra, end=" ")
        print()

anchura = int(input("Anchura del rectángulo: "))
altura = int(input("Altura del rectángulo: "))
caracter = input("Carácter a utilizar: ")

rectangulo(anchura, altura, caracter)

# %%
#%% EJERCICIO 12

def creciente(ancho):
    for i in range(1, ancho + 1):
        for j in range(i):
            print("* ", end="")
        print()

def decreciente(ancho):
    for i in range(1, ancho):
        for j in range(ancho - i):
            print("* ", end="")
        print()

anchura = int(input("Anchura del triángulo: "))
creciente(anchura)
decreciente(anchura)

# %%
#%% EJERCICIO 13

def es_bisiesto(t):
    return t % 400 == 0 or (t % 100 != 0 and t % 4 == 0)

print("Contador de años bisiestos")
inicio = int(input("Escriba un año: "))
print("Escriba otro año posterior a", str(inicio) + ": ", end="")
final = int(input())
while final < inicio:
    print(final, "no es mayor que", str(inicio) + ". Inténtelo de nuevo: ",
          end="")
    final = int(input())

contador = 0
for i in range(inicio, final + 1):
    if es_bisiesto(i):
        contador += 1

print("De", inicio, "a", final, "hay", final - inicio + 1, "años,",
      contador, "de ellos bisiestos.")

# %%
#%% EJERCICIO 15

import random 
  
num = random.randrange(1000,10000)  
                      
n = int(input("Adivina el número de 4 cifras: ")) 
   
if(n == num):              
     print("Encontraste el número en el primer intento!") 
else: 
     ctr = 0    
  
     while(n!=num): 
          ctr += 1                                               
          count = 0  
          n = str(n)                                   
          num = str(num)             
          correct=[]         
     
          for i in range(0,4):  
               
              if(n[i] == num[i]):  
                
                  count += 1    
                  
                  correct.append(n[i])      
              else: 
                  continue
   
          if (count < 4) and (count != 0):      
              print("tienes",count," correctos") 
              print("que son : ") 
                
              for k in correct: 
                  print(k, end=' ') 
  
              print('\n') 
              print('\n') 
              n = int(input("ingresa tu sigueinte elección de números: ")) 
  
          # when none of the digits are guessed correctly. 
          elif(count == 0):          
              print("Ninguno de los digítos es correcto") 
              n=int(input("ingresa tu sigueinte elección de números: "))  
  
     if n==num:                 
         print("Has ganado el juegooooo") 
         print("solo te tomó",ctr,"intentos.")
